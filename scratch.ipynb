# %%
from scripts.get_apis import parse_ini, parse_json, parse_xml
from pathlib import Path

parse_ini(Path("services/config/sabnzbd/sabnzbd.ini"))
# Out:
# '8e85ced08208453481c90d8c4a7ce346'

# %%
from scripts.get_apis import main

main()
# Out:
# prowlarr
# [PosixPath('/Users/brendan/movieseer/services/config/prowlarr/config.xml')]
# homepage
# []
# jellyfin
# []
# qbittorrent
# []
# sabnzbd
# [PosixPath('/Users/brendan/movieseer/services/config/sabnzbd/sabnzbd.ini')]
# radarr
# [PosixPath('/Users/brendan/movieseer/services/config/radarr/config.xml')]
# sonarr
# [PosixPath('/Users/brendan/movieseer/services/config/sonarr/config.xml')]
# jellyseerr
# [PosixPath('/Users/brendan/movieseer/services/config/jellyseerr/settings.json'), PosixPath('/Users/brendan/movieseer/services/config/jellyseerr/settings.old.json')]

# %%
parse_json("services/config/jellyseerr/settings.json")
# Out:
# 'MTc3MTM2MzIwMTA0Mjk5YzI2M2RkLTFkNGYtNDQzZS04OTA3LTBlMDdkYTExYmQ0Yw=='

# %%
from itertools import chain

list(chain(range(0, x) for x in range(1, 3)))
# Out:
# [range(0, 1), range(0, 2)]
