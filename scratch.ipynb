# %%
from movieseer.aggregator.services.arr_models import ArrQueue, ArrHistory


class Test:
    """Shared fields across Radarr and Sonarr history records.

    The aggregator's helpers (_arr_history_status, _format_history) operate
    exclusively on these fields and accept this type directly.
    """

    id: int
    field_1: int
    field_2: str


def identifable(field_name: str):
    def inner(cls: object):
        cls.__setattr__("ids", lambda cls: cls. )

# %%
from typing import TypedDict


class A(TypedDict):
    a: int
    b: str


one = A()

# %%
one["a"] = 1

# %%
one
# Out:
# {'a': 1}

# %%
import os

os.environ["PROWLARR_URL"] = "http://localhost:9696"
os.environ["SABNZBD_URL"] = "http://localhost:8085"
os.environ["QBITTORRENT_URL"] = "http://localhost:8080"
os.environ["JELLYSEERR_URL"] = "http://localhost:5055"

from movieseer.aggregator import Aggregator

agg = Aggregator()
await agg._jellyseer.requests(take=5)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Code/movieseer/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Code/movieseer/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/Code/movieseer/.venv/lib/python3.13/site-packages/httpcore/_async/connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
# ...
